# %%
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from inference import Dataloader

# %%
data = Dataloader()

# %%
data.data
# Out:
#             Systemquality   newPlaces     credit
# month_year
# 2024-01-01      17.648948  149.607082  57.964845
# 2024-02-01      15.803256  119.040567  49.208753
# 2024-03-01      19.381892  122.219646  66.841326
# 2024-04-01      34.002654  112.227085  91.533350
# 2024-05-01      26.460128  136.581975  79.912992
# ...                   ...         ...        ...
# 2033-09-01      21.857691  124.431732  62.573297
# 2033-10-01      11.702175  152.091766  43.355642
# 2033-11-01      19.043618  144.600373  59.148321
# 2033-12-01      22.480528  128.028104  65.086494
# 2034-01-01       2.056976  134.928410  22.389301
#
# [121 rows x 3 columns]

# %%
data.data_train
# Out:
#             Total_Profit
# month_year
# 1994-01-01      5.995331
# 1994-02-01     19.733445
# 1994-03-01     12.030321
# 1994-04-01     11.591842
# 1994-05-01     30.307120
# ...                  ...
# 2023-09-01     17.266384
# 2023-10-01     11.668873
# 2023-11-01     13.414743
# 2023-12-01     15.062235
# 2024-01-01     16.908157
#
# [361 rows x 1 columns]

# %%
data.plot()

# %%
data.data.describe()
# Out:
#        Systemquality   newPlaces      credit
# count     121.000000  121.000000  121.000000
# mean       21.491326  136.002967   64.489628
# std         7.084867   15.621621   15.549985
# min         2.056976   95.486260   22.389301
# 25%        16.550616  124.764709   53.264525
# 50%        21.503635  136.502584   63.537124
# 75%        25.626346  145.091915   74.334360
# max        41.019558  179.716073  103.634353

# %%
data.data_train.describe()
# Out:
#        Total_Profit
# count    361.000000
# mean      14.347876
# std        5.729054
# min        2.603048
# 25%       10.519573
# 50%       13.638019
# 75%       17.703244
# max       37.978602
