# %%
import pandas as pd

# %%
data = pd.read_csv("data/GoldCoast/Not_Scaled/random_0/real_od_matrix.csv")

# %%
data

# %%
data.index = data.iloc[:,0]
data = data.iloc[:,1:]

# %%
data

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(data.values.reshape(len(data.index) * len(data.columns)), density=True, bins=np.arange(0, 0.00005, 0.000005))
# Out:
# (array([200000.,      0.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0.]),
#  array([0.0e+00, 5.0e-06, 1.0e-05, 1.5e-05, 2.0e-05, 2.5e-05, 3.0e-05,
#         3.5e-05, 4.0e-05, 4.5e-05]),
#  <BarContainer object of 9 artists>)
