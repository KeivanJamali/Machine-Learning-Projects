# %%
# %load_ext autoreload
# %autoreload 2

# %%
data_path = "data/data_complete.csv"
import pandas as pd

# data = pd.read_csv(data_path, index_col="Date")
# data = data.iloc[:, 1:]
# data

# %%
import numpy as np
def f1(x):
    return np.log(x+5)

def f2(x):
    return np.exp(x)-5

# %%
import DataLoader, Machine_Model, Engine, Information
from sklearn.preprocessing import MinMaxScaler
import torch
seed = 44
# seed = np.random.randint(0, 1000)
train_percent = 0.7
val_percent = 0.3

test_percent = None
batch_size = 200
torch.manual_seed(seed)

dataloader = DataLoader.MyDataloader(file_path=data_path, 
                                     train_percent=train_percent, 
                                     val_percent=val_percent,
                                     test_percent=test_percent, 
                                     batch_size=batch_size, 
                                     scalers=["StandardScaler"],
                                     func=f1,
                                     func_inverse=f2)
# raise
try:
    print(len(dataloader.train_dataloader), len(dataloader.val_dataloader), len(dataloader.test_dataloader))
except:
    print(len(dataloader.train_dataloader), len(dataloader.val_dataloader))

INPUT_SIZE = 1
HIDDEN_UNITS = 20
OUTPUT_SIZE = 1
DEPTH = 4
model0 = Machine_Model.LSTM_V1(input_size=INPUT_SIZE, hidden_size=HIDDEN_UNITS, output_size=1, depth_number=DEPTH)

EPOCHS = 12000
EPOCHS = 4000
loss_fn = torch.nn.MSELoss()

learning_rate = 0.001
# weight_decay = 0.000082
# weight_decay = 0.0004
weight_decay = 0.00017
optimizer = torch.optim.Adamax(model0.parameters(), learning_rate, weight_decay=weight_decay)
# optimizer = torch.optim.Adamax(model0.parameters(), lr=learning_rate)

engine = Engine.Machine_Engine(model=model0, dataloader=dataloader)
model0_results = engine.fit(loss_fn=loss_fn, 
                            optimizer=optimizer, 
                            epochs_num=EPOCHS, 
                            early_stop_patience=None, 
                            virtualize=False,
                            step_to_print=1)
# Out:
# 1 1
#   0%|          | 0/4000 [00:00<?, ?it/s]
# Epoch 1 | train: Loss 352757.375000 Accuracy -0.2390 | validation: Loss 282349.250000 Accuracy -0.7188
# Epoch 2 | train: Loss 348726.875000 Accuracy -0.2248 | validation: Loss 275020.093750 Accuracy -0.6742
# Epoch 3 | train: Loss 344823.625000 Accuracy -0.2111 | validation: Loss 268273.093750 Accuracy -0.6332
# Epoch 4 | train: Loss 341074.937500 Accuracy -0.1979 | validation: Loss 262105.671875 Accuracy -0.5956
# Epoch 5 | train: Loss 337460.937500 Accuracy -0.1852 | validation: Loss 256430.640625 Accuracy -0.5611
# Epoch 6 | train: Loss 333982.375000 Accuracy -0.1730 | validation: Loss 251254.828125 Accuracy -0.5296
# Epoch 7 | train: Loss 330625.906250 Accuracy -0.1612 | validation: Loss 246551.156250 Accuracy -0.5009
# Epoch 8 | train: Loss 327373.562500 Accuracy -0.1498 | validation: Loss 242186.312500 Accuracy -0.4743
# Epoch 9 | train: Loss 324216.500000 Accuracy -0.1387 | validation: Loss 238190.125000 Accuracy -0.4500
# Epoch 10 | train: Loss 321152.593750 Accuracy -0.1280 | validation: Loss 234534.187500 Accuracy -0.4278
# Epoch 11 | train: Loss 318173.343750 Accuracy -0.1175 | validation: Loss 231192.453125 Accuracy -0.4074
# Epoch 12 | train: Loss 315275.343750 Accuracy -0.1073 | validation: Loss 228113.781250 Accuracy -0.3887
# Epoch 13 | train: Loss 312454.656250 Accuracy -0.0974 | validation: Loss 225255.734375 Accuracy -0.3713
# Epoch 14 | train: Loss 309708.875000 Accuracy -0.0878 | validation: Loss 222636.937500 Accuracy -0.3553
# Epoch 15 | train: Loss 307049.156250 Accuracy -0.0784 | validation: Loss 220212.093750 Accuracy -0.3406
# Epoch 16 | train: Loss 304494.968750 Accuracy -0.0695 | validation: Loss 218000.328125 Accuracy -0.3271
# Epoch 17 | train: Loss 302022.093750 Accuracy -0.0608 | validation: Loss 216017.062500 Accuracy -0.3150
# Epoch 18 | train: Loss 299651.687500 Accuracy -0.0524 | validation: Loss 214254.156250 Accuracy -0.3043
# Epoch 19 | train: Loss 297359.906250 Accuracy -0.0444 | validation: Loss 212693.359375 Accuracy -0.2948
# Epoch 20 | train: Loss 295128.843750 Accuracy -0.0366 | validation: Loss 211292.578125 Accuracy -0.2863
# Epoch 21 | train: Loss 292948.656250 Accuracy -0.0289 | validation: Loss 210107.218750 Accuracy -0.2791
# Epoch 22 | train: Loss 290820.031250 Accuracy -0.0214 | validation: Loss 209136.375000 Accuracy -0.2732
# Epoch 23 | train: Loss 288753.406250 Accuracy -0.0142 | validation: Loss 208282.625000 Accuracy -0.2680
# Epoch 24 | train: Loss 286773.031250 Accuracy -0.0072 | validation: Loss 207620.875000 Accuracy -0.2639
# Epoch 25 | train: Loss 284859.656250 Accuracy -0.0005 | validation: Loss 206888.750000 Accuracy -0.2595
# Epoch 26 | train: Loss 282994.343750 Accuracy 0.0061 | validation: Loss 206201.218750 Accuracy -0.2553
# Epoch 27 | train: Loss 281164.281250 Accuracy 0.0125 | validation: Loss 205556.171875 Accuracy -0.2514
# Epoch 28 | train: Loss 279367.812500 Accuracy 0.0188 | validation: Loss 204951.328125 Accuracy -0.2477
# Epoch 29 | train: Loss 277610.375000 Accuracy 0.0250 | validation: Loss 204383.296875 Accuracy -0.2442
# Epoch 30 | train: Loss 275888.281250 Accuracy 0.0310 | validation: Loss 203842.656250 Accuracy -0.2409
# Epoch 31 | train: Loss 274203.750000 Accuracy 0.0369 | validation: Loss 203329.828125 Accuracy -0.2378
# Epoch 32 | train: Loss 272546.687500 Accuracy 0.0428 | validation: Loss 202849.296875 Accuracy -0.2349
# Epoch 33 | train: Loss 270915.343750 Accuracy 0.0485 | validation: Loss 202439.875000 Accuracy -0.2324
# Epoch 34 | train: Loss 269328.281250 Accuracy 0.0541 | validation: Loss 202070.953125 Accuracy -0.2301
# Epoch 35 | train: Loss 267766.687500 Accuracy 0.0595 | validation: Loss 201722.796875 Accuracy -0.2280
# Epoch 36 | train: Loss 266225.406250 Accuracy 0.0650 | validation: Loss 201367.359375 Accuracy -0.2259
# Epoch 37 | train: Loss 264696.562500 Accuracy 0.0703 | validation: Loss 201025.062500 Accuracy -0.2238
# Epoch 226 | train: Loss 93274.320312 Accuracy 0.6724 | validation: Loss 96774.664062 Accuracy 0.4109
# Epoch 227 | train: Loss 92813.015625 Accuracy 0.6740 | validation: Loss 96670.046875 Accuracy 0.4115
# Epoch 228 | train: Loss 92351.351562 Accuracy 0.6756 | validation: Loss 96572.570312 Accuracy 0.4121
# Epoch 229 | train: Loss 91897.781250 Accuracy 0.6772 | validation: Loss 96484.171875 Accuracy 0.4126
# [INFO] _early_stop_purpose: great!!!
# Epoch 229 | train: Loss 91897.781250 Accuracy 0.6772 | validation: Loss 96484.171875 Accuracy 0.4126

# %%
scaler_x = dataloader.scaler_x[0]
scaler_y = dataloader.scaler_y[0]
scaler_y
# Out:
# StandardScaler()

# %%
for i in engine._inverse_scale(engine.testx[0, -1, 1:].unsqueeze(0), scaler=scaler_x, mode="torch"):
    print(i)
for i in engine._inverse_scale(engine.testx[0, :, 0].unsqueeze(0), scaler=scaler_y, mode="torch"):
    print(i)
engine._inverse_scale(engine.testy[0, :].unsqueeze(0), scaler=scaler_y, mode="torch")
# Out:
# [3.1700000e+02 4.5710000e+03 6.0600000e+02 1.7560000e+03 8.3000000e+01
#  7.7841884e-09 1.0000002e+00 2.1473900e+05 5.4862000e+04]
# [1664. 2027. 2186. 1800. 2216. 2341. 1971. 2136. 2182. 2085. 2272. 2172.
#  2116.]
# array([[2116.]], dtype=float32)

# %%
engine._inverse_scale(engine.testy[0, :].unsqueeze(0), scaler=scaler_y, mode="torch")
# Out:
# array([[2116.]], dtype=float32)

# %%
d = dataloader.train_datas[dataloader.features+dataloader.target]
d.plot(figsize=(30, 20));

# %%
dd = dataloader.val_datas[dataloader.features+dataloader.target]
dd.plot(figsize=(30, 20));

# %%
engine.plot_predict_real(epoch=-150)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 engine.plot_predict_real(epoch=-150)
#
# TypeError: Machine_Engine.plot_predict_real() missing 5 required positional arguments: 'save', 'train_loss', 'train_acc', 'val_lss', and 'val_acc'

# %%
engine.plot_loss()
engine.plot_acc()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 engine.plot_loss()
# ----> 2 engine.plot_acc()
#
# File d:\All Python\Machine-Learning-Projects\Project 7 - Health\Engine.py:350, in Machine_Engine.plot_acc(self, save)
#     348 t_a = self.results["train_acc"]
#     349 t_a = [100 * i if i > 0 else 0 for i in t_a]
# --> 350 plt.plot(range(len(self.result["train_acc"])), t_a, label="train")
#     351 plt.plot(range(len(self.result["val_acc"])), v_a, label="val")
#     352 plt.legend()
#
# AttributeError: 'Machine_Engine' object has no attribute 'result'

# %%
engine.save()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 engine.save()
#
# NameError: name 'engine' is not defined

# %%
test_loss, test_acc, true_predict_list = engine.test(loss_fn=loss_fn)
test_acc

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs

# %%
dataloader.scaler_y.inverse_transform(engine.ys)
# Out:
# array([[2860.8813],
#        [2658.3875],
#        [2673.7876],
#        [2965.0305],
#        [2812.3303],
#        [2942.8152],
#        [3016.6838],
#        [3158.9995],
#        [2772.727 ],
#        [2815.1633],
#        [3538.33  ],
#        [3532.1099],
#        [3599.0664],
#        [3579.058 ],
#        [3557.9473],
#        [3510.812 ],
#        [3563.7153],
#        [3501.8062],
#        [3491.3872],
#        [3472.835 ],
#        [3377.545 ]], dtype=float32)

# %%
import numpy as np
x3 = np.array([[2870, 5751, 5714, 591908, 9468, 153304, 51022, 3441, 0],
      [2780, 5751, 5714, 591908, 9468, 153304, 51022, 3441, 0],
      [2319, 5751, 5714, 591908, 9468, 153304, 51022, 3441, 0],
      [2901, 5751, 5714, 591908, 9468, 153304, 51022, 3441, 0],
      [3933, 4639, 4270, 822597, 9468, 208977, 47243, 2312, 0],
      [3519, 4639, 4270, 822597, 9468, 208977, 47243, 2312, 0],
      [3583, 4639, 4270, 822597, 9468, 208977, 47243, 2312, 0],
      [3870, 4639, 4270, 822597, 9468, 208977, 47243, 2312, 0]])

# %%
for i in range(7,8):
    name = Information.features[i]
    x3 = data[Information.features].iloc[88:,:]
    x2 = x3.iloc[:, i]
    x2[95] = x2[95]+1

    engine.predict(x3, dataloader.scaler_y, dataloader.scaler_x, n=12)
    engine.prediction.to_csv(f"data_distinc/health_prediction_{name}.csv")
    engine.prediction = None
# Out:
# C:\Users\keipj\AppData\Local\Temp\ipykernel_736\3139872168.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x2[95] = x2[95]+1

# %%
engine.predict(x3, dataloader.scaler_y, dataloader.scaler_x, n=12)
# Out:
# <bound method Machine_Engine.predict of <Engine.Machine_Engine object at 0x0000016E880EAB50>>

# %%
engine.prediction.to_csv("health_prediction_covid.csv")

# %% [markdown]
# # Deployment of Health model

# %%
import Machine_Model, Engine, Information
from pathlib import Path
import torch

INPUT_SIZE = 1
HIDDEN_UNITS = 18
OUTPUT_SIZE = 1
DEPTH = 4

model1 = Machine_Model.LSTM_V0(input_size=INPUT_SIZE, hidden_size=HIDDEN_UNITS, output_size=3, depth_number=DEPTH)
model2 = Machine_Model.NN_V0(input_size=17, hidden_size=HIDDEN_UNITS, output_size=OUTPUT_SIZE)

model1_path = "Health_RNN_V0_N1.pt"
model2_path = "Health_RNN_V0_N2.pt"

model1.load_state_dict(torch.load("model/RNN/" + model1_path))
model2.load_state_dict(torch.load("model/RNN/" + model2_path))

model1_size = Path("model/RNN", model1_path).stat().st_size // (1024)
model2_size = Path("model/RNN", model2_path).stat().st_size // (1024)
print(f"model 1 size: {model1_size} KB")
print(f"model 2 size: {model2_size} KB")
# Out:
# model 1 size: 43 KB
# model 2 size: 2 KB

# %%
health_demo_path = Path("demos/Health_Tourists/")
health_demo_path.mkdir(parents=True, exist_ok=True)

# %%
# %%writefile demos/Health_Tourists/model.py
import torch
import torchvision
from torch import nn


def create_effnetb2_model(num_classes:int=101,
                          seed:int=42):
    weights = torchvision.models.EfficientNet_B2_Weights.DEFAULT
    transforms = weights.transforms()
    model = torchvision.models.efficientnet_b2(weights=weights)

    for param in model.parameters():
        param.requires_grad = False
        
    torch.manual_seed(seed)
    model.classifier = nn.Sequential(
        nn.Dropout(p=0.3, inplace=True),
        nn.Linear(in_features=1408, out_features=num_classes)
    )
    
    return model, transforms
